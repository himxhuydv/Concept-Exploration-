# %% [markdown]
# **SOME BASIC TERMOLOGY I AND YOU SHOULD KNOW ABOUT THAT.**

# %% [markdown]
# **Question**1:What do you mean by  **Iterables,Iteration and Iterate**
# Answer1:  **Iterables**:
# Something you can access item by item and **loop through.**
# For Example:
# ``` for item in iterables(): ```
#
#
# **Iteration**:
# Mean a each loop completion(*if say print whole values from the list then the first values which you take from the list and store that in to the i variables this whole proces is called iteration*)or you can say acessing each item from the iterables and complety printing it or do some operation is called Iteration.
#
# For Example:
# ```for i in [10,20,30]: ```
# ``` print(i)```
#
# [10]:this is the first iteration
# [20]:this  is the second iteration
# [30]:this is the third iteration
#
# **Iterate**:
# Mean going to each item one by one.if we have a list then the  loop will iterate over the list (**mean acess the values**)

# %% [markdown]
# **Question2**:What do you mean by **placeholder?**
# Answer2:
